# %% [markdown]
# <a href="https://colab.research.google.com/github/karenrivgi/talleresGoogleColab/blob/main/Taller_08_gr%C3%A1ficos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## «El grado sumo del saber es contemplar el porqué»
#
# ### [Sócrates](https://es.wikipedia.org/wiki/S%C3%B3crates)

# %% [markdown]
# # Taller 08 Gráficos Matplotlib
# En este taller aprenderá los conceptos básicos de Python 3 relativos a manejo de gráficos con la librería [Matplotlib](https://matplotlib.org/).

# %% [markdown]
# ## Referencias
#
# Este taller se basa en información e ideas recopiladas de las siguientes fuentes:
#
# * [The Python Graph Gallery](https://python-graph-gallery.com/all-charts/)
# * [Matplotlib Gallery](https://matplotlib.org/gallery/index.html)
# * [Tutorial de Matplotlib en Español](https://deepnote.com/@anthonymanotoa/Tutorial-de-Matplolib-en-Espanol-a8031a06-641a-4cef-98ff-a0664ac0c659)
# * [A Beginner’s Guide to matplotlib for Data Visualization and Exploration in Python](https://www.analyticsvidhya.com/blog/2020/02/beginner-guide-matplotlib-data-visualization-exploration-python/?utm_source=feedburner&utm_medium=email&utm_campaign=Feed%3A+AnalyticsVidhya+(Analytics+Vidhya))
# * [Gráficos con Matplotlib](https://www.kaggle.com/code/carlosgm9/gr-ficos-con-matplotlib)
#
# En [6 Essential Data Visualization Python Libraries – Matplotlib, Seaborn, Bokeh, Altair, Plotly, GGplot](https://www.analyticsvidhya.com/blog/2020/03/6-data-visualization-python-libraries/?utm_source=feedburner&utm_medium=email&utm_campaign=Feed%3A+AnalyticsVidhya+(Analytics+Vidhya)) encontrará un análisis comparativo de seis librerías de Python para visualización de datos

# %% [markdown]
# # Introducción a Matplotlib
#
# En ocasiones tener los datos como resultado de un proceso no es suficiente para entender un problema y por ello se hace necesario buscar maneras donde sea más fácil entenderlos. **Matplotlib** es una librería que permite graficar datos de una manera rápida y flexible, a continuación, se muestra como graficar una línea con base en unos valores con **Matplotlib**.
#
# Este taller se basa en:
#
# https://matplotlib.org/3.1.0/tutorials/introductory/pyplot.html

# %% [markdown]
# # Los gráficos (plot)
#
# Los gráficos permiten mostrar la relación entre dos variables.

# %%
# importar librería
import matplotlib.pyplot as plt

# generar datos
datos = range(0,100)

# generar gráfico
plt.plot(datos, 'c')

# establecer etiquetas de los ejes
plt.xlabel ('etiqueta eje horizontal')
plt.ylabel('etiqueta eje vertical')

# establecer el título del gráfico
plt.title('Toro ese llanto por nara')

# mostrar gráfico
plt.show()

# %% [markdown]
# ### gráficos con dos variables explícitas

# %%
# importar librería
import matplotlib.pyplot as plt

# generar gráfico de una lista vs. otra lista
plt.plot([1, 2, 3, 4], [1, 4, 9, 16], 'y^')

# establecer etiquetas de los ejes
plt.xlabel ('primera lista')
plt.ylabel('segunda lista')

# establecer el título del gráfico
plt.title('Título del gráfico')

# mostrar gráfico
plt.show()

# %% [markdown]
# ### ¿Cómo dar formato a los gráficos?
#
# Se pueden construir gráficos con diferentes formatos:
# * 'o' le dice a Pyplot que debe usar puntos en la representación
# * '--' le dice a Pyplot que debe usar una línea punteada en la representación
# * '^' le dice a Pyplot que debe usar triángulos en la representación
# * '' le dice a Pyplot que debe usar una línea en la representación
#
# y con diferentes colores
# * 'r' es rojo
# * 'b' es azul
# * 'g' es verde
# * 'y' es amarillo
#
# Además del color y la forma puede agregar otros parámetros para graficar , intente con **linewidth=2.0** para cambiar el ancho de la línea en la función **plot**

# %%
# importar librería
import matplotlib.pyplot as plt

# generar gráfico con puntos rojos
plt.plot([1, 2, 3, 4], [1, 4, 9, 16], linewidth = 10)

# configurar los ejes horizontal y vertical
plt.axis([0, 5, 0, 18])
        #   x     y

# establecer etiquetas de los ejes
plt.xlabel ('etiqueta eje horizontal')
plt.ylabel('etiqueta eje vertical')

# establecer el título del gráfico
plt.title('Título del gráfico')

# mostrar gráfico
plt.show()

# %% [markdown]
# ### gráficos con listas

# %%
# importar las librerías requeridas
import matplotlib.pyplot as plt
import numpy as np

# generar un arreglo con datos separados 0.2
t = np.arange(0., 5., 0.2)

# graficar líneas rojas, cuadrados azules y triángulos verdes
plt.plot(t, t, 'r--', t, t**2, 'bs', t, t**3, 'g^') # Se pueden plotear múltiples funciones en una misma gráfica, esto puede afectar las dimensiones de la gráfica

# establecer etiquetas de los ejes
plt.xlabel ('etiqueta eje horizontal')
plt.ylabel('etiqueta eje vertical')

# establecer el título del gráfico
plt.title('Título del gráfico')

# mostrar gráfico
plt.show()

# %% [markdown]
# ### gráfico de raíces

# %%
# importar las librerías requeridas
import matplotlib.pyplot as plt
import numpy as np

# generar lista de numeros en 0 y 1000 con un delta de 1
x = np.arange(0, 100, 1) 

# generar las raices cuadradas de x
y = x**0.5 

# graficar la raíz positiva de x en amarillo con línea de ancho 2
plt.plot(x, y, 'y', linewidth=2.0) 

# graficar la raíz negativa de x en azul con linea de ancho 4
plt.plot(x, -y, 'b', linewidth=2.0) 

plt.title("Gráfica de las raíces de X") # Título
plt.ylabel('Raíces de X')
plt.xlabel('Valores de X')

plt.show()

# %% [markdown]
# ### gráficos a partir de diccionarios

# %%
# importar las librerías requeridas
import matplotlib.pyplot as plt
import numpy as np

# generar los datos
datos = {'primero': np.arange(50),
         'segundo' : np.arange(50) + 10 * np.random.randn(50),
        'tercero': np.random.randint(0, 50, 50),
        'cuarto': np.random.randn(50)}


# generar el gráfico con las claves del diccionario - gráfico de dispersióm(?)
plt.scatter('primero', 'segundo', 'tercero', 'cuarto',  data=datos)

# generar etiquetas
plt.xlabel('eje x')
plt.ylabel('eje y')
# Out:
# Text(0, 0.5, 'eje y')

# %% [markdown]
# ## gráficos apilables

# %%
# importar las librerías requeridas
import matplotlib.pyplot as plt
import numpy as np

# generar los datos
x = [1, 2, 3, 4, 5]
fibo = [1, 1, 2, 3, 5]
par = [0, 4, 2, 6, 8]
impar = [1, 3, 5, 7, 9]

# generar los nombres
nombres = ["Fibonacci ", "Pares", "Impares"]

# crear la figura
fig, ax = plt.subplots() 
ax.stackplot(x, fibo, par, impar, labels=nombres) # gráfico apilable
ax.legend(loc='upper left')

plt.show()

# %% [markdown]
# # Elementos de una figura
#
# El siguiente código muestra los diferentes elementos que componen una figura en matplotlib
#
# Código adaptado de https://matplotlib.org/examples/showcase/anatomy.html

# %%
# Este código muestra los lementos que componen una figura en matplotlib

# importar las librerías necesarias
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import AutoMinorLocator, MultipleLocator, FuncFormatter

# definir función para ubicar los marcadores
def minor_tick(x, pos):
    if not x % 1.0:
        return ""
    return "%.2f" % x

# definir función para generar círculos
def circle(x, y, radius=0.15):
    '''Función que grnera círculos'''
    from matplotlib.patches import Circle
    from matplotlib.patheffects import withStroke
    circle = Circle((x, y), radius, clip_on=False, zorder=10, linewidth=1,
                    edgecolor='black', facecolor=(0, 0, 0, .0125),
                    path_effects=[withStroke(linewidth=5, foreground='w')])
    ax.add_artist(circle)

# definir función para personalizar textos
def text(x, y, texto):
    '''Función que permite personalizar los textos dentro de un gráfico'''
    ax.text(x, y, texto, backgroundcolor="white",
            ha='center', va='top', weight='bold', color='blue')

# establecer una semilla para la generación de los números aleatorios
np.random.seed(19680801)


# generar los datos a graficar
X = np.linspace(0.5, 3.5, 100)
Y1 = 3+np.cos(X)
Y2 = 1+np.cos(1+X/0.75)/2
Y3 = np.random.uniform(Y1, Y2, len(X))

# crear una figura de un tamaño preestablecido
fig = plt.figure(figsize=(10, 10))

# asignar un nombre a la figura y agregar el espacio para los gráficos auxiliares
ax = fig.add_subplot(1, 1, 1, aspect=1)


# ubicar los marcadores
ax.xaxis.set_major_locator(MultipleLocator(1.000))
ax.xaxis.set_minor_locator(AutoMinorLocator(4))
ax.yaxis.set_major_locator(MultipleLocator(1.000))
ax.yaxis.set_minor_locator(AutoMinorLocator(4))
ax.xaxis.set_minor_formatter(FuncFormatter(minor_tick))

# establecer los límites de los ejes
ax.set_xlim(0, 4)
ax.set_ylim(0, 4)

# configurar los marcadores
ax.tick_params(which='major', width=1.0)
ax.tick_params(which='major', length=10)
ax.tick_params(which='minor', width=1.0, labelsize=10)
ax.tick_params(which='minor', length=5, labelsize=10, labelcolor='0.25')

# agregar una rejilla al gráfico
ax.grid(linestyle="--", linewidth=0.5, color='.25', zorder=-10)

# configurar los elementos que se van a graficar
ax.plot(X, Y1, c=(0.25, 0.25, 1.00), lw=2, label="Línea azul", zorder=10)
ax.plot(X, Y2, c=(1.00, 0.25, 0.25), lw=2, label="Línea roja")
ax.plot(X, Y3, linewidth=0,
        marker='o', markerfacecolor='w', markeredgecolor='k')

# establecer título y etiquetas
ax.set_title("Elementos de una figura", fontsize=20, verticalalignment='bottom')
ax.set_xlabel("eje X")
ax.set_ylabel("eje Y")

# establecer las leyendas
ax.legend()

# indicador de marcador auxiliar
circle(0.50, -0.10)
text(0.50, -0.32, "etiqueta marcador auxiliar")

# indicador de marcador principal
circle(-0.03, 4.00)
text(0.03, 3.80, "etiqueta marcador principal")

# indicar etiqueta eje X
circle(2, 0, 0.40)
text(2, -0.45, "etiqueta eje X")

# indicar etiqueta eje Y
circle(-0.27, 2, 0.40)
text(-0.27, 1.6, "etiqueta eje Y")

# indicar etiqueta título
#circle(1.60, 4.13)
#text(1.60, 3.93, "Título")

# indicar línea roja
circle(1.20, 0.60)
text(1.20, 0.40, "Línea\n(gráfico de línea)")

# indicar gráfico de dispersión
circle(1.20, 1.75)
text(1.20, 1.55, "Marcadores\n(gráfico de dispersión)")

# indicar rejilla
circle(3.00, 3.00)
text(3.00, 2.80, "Rejilla")

# indicar leyenda
circle(3.70, 3.80)
text(3.70, 3.60, "Leyenda")

color = 'green'

# flecha hacia la derecha
ax.annotate('Ejes', xy=(4.0, 0.75), xycoords='data',
            xytext=(3.3, 0.5), textcoords='data',
            weight='bold', color=color,
            arrowprops=dict(arrowstyle='->',
                            connectionstyle="arc3",
                            color=color))
# flecha hacia la izquierda
ax.annotate('', xy=(3.2, 0.0), xycoords='data',
            xytext=(3.45, 0.45), textcoords='data',
            weight='bold', color=color,
            arrowprops=dict(arrowstyle='->',
                            connectionstyle="arc3",
                            color='red'))

ax.text(4.0, -0.4, "Elaborado con http://matplotlib.org",
        fontsize=10, ha="right", color='.5')

plt.show()

# %% [markdown]
# ### Exploración
#
# Copia a continuación el código que se encuentra en la anterior celda y ensaye a modificar los diferentes parámetros.
#
# Observe y analice los efectos de los cambios efectuado en los parámetros

# %%
# Copie a continuación el código y explore lo que sucede al modificar los parámetros

# %% [markdown]
# ### ejemplo de figura

# %%
# importar las librerías requeridas
import matplotlib.pyplot as plt
import numpy as np

# generar los datos
x = np.linspace(0, 2, 100)

# crear la figura y asignar un tamaño
plt.figure(figsize=(10, 10)) 

# establecer los componentes de la figura
plt.plot(x, x, label='lineal')
plt.plot(x, x**2, label='cuadrática')
plt.plot(x, x**3, label='cúbica')

# establecer los nombres de los ejes
plt.xlabel('eje x')
plt.ylabel('eje y')

# establecer el título de la figura
plt.title("Figura simple")

# generar el recuadro con las leyendas
plt.legend()

plt.show()

# %% [markdown]
# ### Generación de varios gráficos en un mismo espacio
#
# Puede graficar múltiples funciones con el uso de la función figure de pyplot, esta crea un "espacio" en el grafo principal que le permite dividir el espacio en n filas y m columnas, solo debe agregar subplots a la figura:

# %%
# Gráfico de múltiples funciones en coordenadas polares y ordenadas

# importar las librerías requeridas
import matplotlib.pyplot as plt
import numpy as np

# valores que tomará X estan entre 0 y 2PI con un delta de 0.1
x = np.arange(0,2*np.pi,0.1) 

# rosa polar de cinco pétalos (5*np.cos(5*x))
rosa_polar = 1*np.cos(1*x) 

# espiral de Arquímedes (5 + 50*x)
espiral_arquimedes = 10 + 100*x 

# función seno de x
seno = np.sin(2*x)  

# la función figure crea un "espacio" donde almacenar diferentes graficas
fig = plt.figure() 

# graficar rosa polar de 5 petalos
ax = fig.add_subplot(221, projection="polar")  # Filas, columnas, indica en qué posición de la partición que hizo se graficará la figura (relativo a cada gráfico): en que se divide el espacio en que se grafica
ax.plot(rosa_polar,color="cyan",linewidth=3)   # En ese caso, 2 filas, 2 columnas y la pone en la posición 1


# graficar espiral de arquimedes
ax = fig.add_subplot(222, projection="polar") # En ese caso, 2 filas, 2 columnas y la pone en la posición 1
ax.plot(espiral_arquimedes,color="black",linewidth=2) # G

# graficar seno de x en la posición (212)
ax = fig.add_subplot(212) # En ese caso, 2 filas, 1 columnas y la pone en la posición 2, es decir la correspondiente a las 3-4 de las gráficas anteriores
ax.plot(seno,color="black",linewidth=2) 

# mostrar las gráficas
plt.show()

# %% [markdown]
# ### Aclaración
#
# * La rosa es graficada en ese espacio pues para ella la figura está divida en 2x2 y esta ocupa el primer espacio, lo que le da la esquina superior izquierda.
# * La función seno es graficada en ese espacio pues para ella la figura está dividida en 2x1 y ocupa el segundo espacio, lo que le da toda la parte baja de la figura.

# %% [markdown]
# ### incluyendo anotaciones en los gráficos

# %%
# importar las librerías requeridas
import matplotlib.pyplot as plt
import numpy as np

# generar los datos
t = np.arange(0.0, 5.0, 0.01)
s = np.cos(2*np.pi*t)
#s = np.cos(0.5*np.pi*t)

# generar un gráfico con una línea de ancho 3
plt.plot(t, s, lw=3) #linewidth

# generar los límites del eje y
plt.ylim(-1.5, 2)

# generar anotación
plt.annotate('máximo local', xy=(2, 1), xytext=(3, 1.8), # Mirando la gráfica se tomaron estos valores
             arrowprops=dict(facecolor='black', shrink=0.05),
             )

plt.show()

# %% [markdown]
# ### gráficos con variables categóricas

# %%
# importar las librerías requeridas
import matplotlib.pyplot as plt
import numpy as np

# generar nombres y datos
nombres = ['grupo_a', 'grupo_b', 'grupo_c', 'grupo_d']
valores = [1, 10, 100, 50]

# crear la figura
plt.figure(figsize=(12, 3))

# representación con barras
plt.subplot(131)
plt.bar(nombres, valores)

# representación con puntos
plt.subplot(132)
plt.scatter(nombres, valores)

# representación con líneas
plt.subplot(133)
plt.plot(nombres, valores)

# generar título superior
plt.suptitle('Representación de variables categóricas')

plt.show()

# %% [markdown]
# ### gráficos de barras apilados

# %%
# importar las librerías requeridas
import matplotlib.pyplot as plt
import numpy as np

# generar los datos
n = 5
promHombres = (20, 35, 30, 35, 27)
promMujeres = (25, 32, 34, 20, 25)

# ubicar en el eje x los grupos
ind = np.arange(n)    

# establecer el ancho de las barras
width = 0.35

# generar los gráficos
p1 = plt.bar(ind, promHombres, width)
p2 = plt.bar(ind, promMujeres, width,
             bottom=promHombres)

# establecer las etiquetas
plt.ylabel('Marcadores')
plt.title('Marcadores por grupo y género')
plt.xticks(ind, ('G1', 'G2', 'G3', 'G4', 'G5'))
plt.yticks(np.arange(0, 81, 10))
plt.legend((p1[0], p2[0]), ('Hombres', 'Mujeres'))

plt.show()

# %% [markdown]
# ### varias figuras y varios ejes

# %%
# importar las librerías requeridas
import matplotlib.pyplot as plt
import numpy as np

# función para transformar los datos
def f(t):
    return np.exp(-t) * np.cos(2*np.pi*t)

# generar los valores para t1 y t2
t1 = np.arange(0.0, 5.0, 0.1)
t2 = np.arange(0.0, 5.0, 0.02)

# crear la figura
plt.figure()

# crear primer subgráfico
plt.subplot(211)
plt.plot(t1, f(t1), 'bo', t2, f(t2), 'k')

# crear segundo subgráfico
plt.subplot(212)
plt.plot(t2, np.cos(2*np.pi*t2), 'r--')

plt.show()

# %% [markdown]
# ### histograma

# %%
# importar las librerías requeridas
import matplotlib.pyplot as plt
import numpy as np

# generar los datos de una distribución normal
mu = 100
sigma = 15
x = mu + sigma * np.random.randn(10000)

# crear el histograma de los datos
n, bins, patches = plt.hist(x, 50, density=1, facecolor='g', alpha=0.75)

# generar etiquetas y títulos
plt.xlabel('datos')
plt.ylabel('probabilidad')
plt.title('histograma de datos')
plt.text(60, .025, r'$\mu=100,\ \sigma=15$')

# generar límites de los ejes
plt.axis([40, 160, 0, 0.03])

# generar rejilla
plt.grid(True)

plt.show()

# %% [markdown]
# # Matplotlib 3D
#
# Graficar en 3D es similar a graficar en 2D, solo debe crear una función de varias variables (en este caso tres) y aplicarla a un gráfico.
#
# **Nota: Para graficar en Matplotlib en 3D consulte http://matplotlib.org/mpl_toolkits/mplot3d/tutorial.html. El uso de estas librerías requiere de un conocimiento mayor y de funciones de varias variables por lo tanto se deja a criterio del estudiante su aprendizaje.**

# %%
# Gráfico de una esfera de radio 10
import matplotlib.pyplot as plt
import numpy as np
from mpl_toolkits.mplot3d import Axes3D


fig = plt.figure()
ax = Axes3D(fig)

# Se generan los posibles valores para los parametros u, v
u = np.linspace(0, 2 * np.pi, 100) 
v = np.linspace(0, np.pi, 100)

# Se calculan los vectores x, y, z
x = 10 * np.outer(np.cos(u), np.sin(v))
y = 10 * np.outer(np.sin(u), np.sin(v))
z = 10 * np.outer(np.ones(np.size(u)), np.cos(v))

# Graficar vectores en azul
ax.plot_wireframe(x, y, z, color='b') # Prueba a cambiar "plot_wireframe" por "plot_surface"

plt.show()
# Out:
# <ipython-input-29-928898ce6773>:8: MatplotlibDeprecationWarning: Axes3D(fig) adding itself to the figure is deprecated since 3.4. Pass the keyword argument auto_add_to_figure=False and use fig.add_axes(ax) to suppress this warning. The default value of auto_add_to_figure will change to False in mpl3.5 and True values will no longer work in 3.6.  This is consistent with other Axes classes.
#   ax = Axes3D(fig)

# %% [markdown]
# #  Gráfico con datos faltantes e índices de fecha

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

dates = pd.date_range('20160301', periods=6, freq='D')

numbers = np.arange(10, 16)

ts = pd.Series([1,3,5,np.nan,6,8], index=dates)

print(ts)

ts.plot()

plt.show()
# Out:
# 2016-03-01    1.0
# 2016-03-02    3.0
# 2016-03-03    5.0
# 2016-03-04    NaN
# 2016-03-05    6.0
# 2016-03-06    8.0
# Freq: D, dtype: float64

# %% [markdown]
# # Datos mina

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Datos reales de mina
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

values = pd.read_csv('/content/drive/MyDrive/2023-I/Programación para ingeniería/Carbon_v3.csv')
# print (values)

values.plot()

plt.show()

# %%
# Datos reales de mina
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

values = pd.read_csv('/content/drive/MyDrive/2023-I/Programación para ingeniería/Carbon_v3.csv')
# print (values)

values.plot()

plt.savefig('Carbones_v4.jpg')

# %% [markdown]
# # Aplicaciones

# %% [markdown]
# ## Resultados pruebas SABER 2016-02

# %%
# importar las librerías requeridas
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import openpyxl

# cargar los datos
df = pd.read_csv('/content/drive/MyDrive/2023-I/Programación para ingeniería/saber11_20162.csv', sep=',')

# seleccionar el municipio deseado 5001
datos = df[df.CODIGOMUNICIPIO == 5001 ] # Medellin
#datos = df[df.JORNADA == 'COMPLETA']

# calcular los promedios
promedios = datos.iloc[:, 9:14]
df3 = pd.DataFrame(promedios.values, index=datos['NOMBREINSTITUCION'], columns=promedios.columns)
promedios = df3.mean(1)

# organizar promedios en orden descendente y graficar
promedios = promedios.sort_values(ascending=False)
promedios[:10].plot(kind='barh')
plt.show()

print(promedios[:10])


# organizar promedios en orden descendente y graficar
promedios = promedios.sort_values()
promedios[:10].plot(kind='barh')
plt.show()

print(promedios[:10])
# Out:
# NOMBREINSTITUCION
# COL MONTESSORI                      74.318
# COL SAN IGNACIO DE LOYOLA           71.814
# COL DE LA COMPANIA DE MARIA         71.664
# COMUNIDAD COLEGIO DE JESUS MARIA    71.114
# COL GIMN LOS PINARES                71.086
# INST JORGE ROBLEDO                  70.682
# COL CORAZONISTA                     70.210
# COL CAMPESTRE LA COLINA             69.506
# COL SAN JOSE DE LAS VEGAS           69.196
# COL CALASANZ                        68.912
# dtype: float64
# NOMBREINSTITUCION
# COL LUIS AMIGO Y FERRER                                           14.542
# INST EDUC CORVIDE - SEDE PRINCIPAL                                26.108
# CENT EDUC DE CÓMPUTO EMPRESARIAL PARA EL TRABAJO - CINDECÓPUTO    37.000
# COL CEDEPRO                                                       40.500
# COL FE Y ALEGRIA SANTA MARIA                                      40.592
# COL CEDEPRO                                                       40.710
# INST EDUC PEDAGOGICO INTEGRAL                                     40.720
# COL EXTERNADO PATRIA - SEDE CENTRO                                41.452
# COL GENTE UNIDA JOVENES POR LA PAZ-SANTO DOMINGO                  41.526
# INST EDUC PEDAGOGICO INTEGRAL                                     41.640
# dtype: float64

# %%
df.head()
# Out:
#    CODINST                   NOMBREINSTITUCION  CODIGOMUNICIPIO  \
# 0       59                      INST EDUC CEFA             5001
# 1       75  INST EDUC SANTOS ANGELES CUSTODIOS             5001
# 2       83               COL BARBARA MICARELLI             5001
# 3       91                     COL BETHLEMITAS             5001
# 4      125               COL CALASANZ FEMENINO             5001
#
#   NOMBREMUNICIPIO DEPARTAMENTO CALENDARIO  NATURALEZA   JORNADA  EVALUADOS  \
# 0        MEDELLIN    ANTIOQUIA          A     OFICIAL    MAÑANA        968
# 1        MEDELLIN    ANTIOQUIA          A     OFICIAL    MAÑANA         49
# 2        MEDELLIN    ANTIOQUIA          A  NO OFICIAL  COMPLETA         30
# 3        MEDELLIN    ANTIOQUIA          A  NO OFICIAL  COMPLETA         69
# 4        MEDELLIN    ANTIOQUIA          A  NO OFICIAL  COMPLETA         66
#
#    PROMLECTURACRITICA  PROMMATEMATICA  PROMSOCIALESYCIUDADANAS  \
# 0               57.75           54.95                    55.45
# 1               52.46           46.57                    49.14
# 2               63.43           60.26                    61.73
# 3               64.76           65.02                    63.91
# 4               64.30           62.46                    61.18
#
#    PROMCIENCIASNATURALES  PROMINGLES  DESVLECTURACRITICA  DESVMATEMATICA  \
# 0                  56.15       55.33                8.05            9.00
# 1                  50.32       54.65                8.43            8.73
# 2                  60.90       62.86                6.26            7.42
# 3                  63.91       75.59                6.87            7.07
# 4                  61.46       65.95                7.21            8.64
#
#    DESVSOCIALESYCIUDADANAS  DESVCIENCIASNATURALES  DESVINGLES  PERIODO
# 0                     8.44                   7.63        9.91    20162
# 1                    10.52                   7.98       10.68    20162
# 2                     6.82                   5.92        8.18    20162
# 3                     5.48                   7.29        8.54    20162
# 4                     7.93                   5.88       10.49    20162

# %% [markdown]
# ## Ejemplos con pruebas Saber 2016-02

# %% [markdown]
# ### paso 0 importar librerías requeridas, cargar datos, validar datos cargados

# %%
# importar las librerías requeridas
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import openpyxl

# los estilos se pueden consultar en https://python-graph-gallery.com/199-matplotlib-style-sheets/
plt.style.use('seaborn')

# cargar los datos
saber2016_df = pd.read_csv('/content/drive/MyDrive/2023-I/Programación para ingeniería/saber11_20162.csv', sep=',')
saber2016_df.head(2)
# Out:
#    CODINST                   NOMBREINSTITUCION  CODIGOMUNICIPIO  \
# 0       59                      INST EDUC CEFA             5001
# 1       75  INST EDUC SANTOS ANGELES CUSTODIOS             5001
#
#   NOMBREMUNICIPIO DEPARTAMENTO CALENDARIO NATURALEZA JORNADA  EVALUADOS  \
# 0        MEDELLIN    ANTIOQUIA          A    OFICIAL  MAÑANA        968
# 1        MEDELLIN    ANTIOQUIA          A    OFICIAL  MAÑANA         49
#
#    PROMLECTURACRITICA  PROMMATEMATICA  PROMSOCIALESYCIUDADANAS  \
# 0               57.75           54.95                    55.45
# 1               52.46           46.57                    49.14
#
#    PROMCIENCIASNATURALES  PROMINGLES  DESVLECTURACRITICA  DESVMATEMATICA  \
# 0                  56.15       55.33                8.05            9.00
# 1                  50.32       54.65                8.43            8.73
#
#    DESVSOCIALESYCIUDADANAS  DESVCIENCIASNATURALES  DESVINGLES  PERIODO
# 0                     8.44                   7.63        9.91    20162
# 1                    10.52                   7.98       10.68    20162

# %% [markdown]
# ### paso 1 mirar la información en tablas
#
# saber2016_table = pd.pivot_table(data=saber2016_df,index='NATURALEZA',values='EVALUADOS',aggfunc=np.sum)
# saber2016_table

# %%
saber2016_table = pd.pivot_table(data=saber2016_df,index='NATURALEZA',values='EVALUADOS',aggfunc=np.sum)
saber2016_table
# Out:
#             EVALUADOS
# NATURALEZA
# NO OFICIAL     137771
# OFICIAL        414921

# %%
saber2016_table_2 = pd.pivot_table(data=saber2016_df,index='NATURALEZA',values='PROMLECTURACRITICA',aggfunc=np.mean)
# saber2016_table_2
print(saber2016_table_2)
# Out:
#             PROMLECTURACRITICA
# NATURALEZA
# NO OFICIAL           54.526238
# OFICIAL              49.951799

# %% [markdown]
# ### paso 2 graficar la información de una tabla

# %%
#print(saber2016_table.index)
# gráfico de barras
plt.bar(saber2016_table.index,saber2016_table['EVALUADOS'])

#xticks 
plt.xticks(rotation=70) 

# etiqueta eje x
plt.xlabel('Tipo de institución') 

# etiqueta eje y
plt.ylabel('Estudiantes evaluados') 

# título del gráfico
plt.title('Total estudiantes') 

# guardar el gráfico
plt.savefig('saber2016_bar.png',dpi=300,bbox_inches='tight') 

# mostrar el gráfico en pantalla
plt.show()

# %% [markdown]
# # Ejercicios
#
# Busque tres bases de datos en [Datos Abiertos](https://www.datos.gov.co/) y haga análisis gráfico de sus contenidos.

# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv('/content/drive/MyDrive/2023-I/Programación para ingeniería/1000_Empresas_mas_grandes_del_pa_s.csv')
df.head(2)
# Out:
#    No.        NIT              RAZON SOCIAL       SUPERVISOR  \
# 0    1  899999068             ECOPETROL S.A  SUPERFINANCIERA
# 1    2  830095213  ORGANIZACIÓN TERPEL S.A.  SUPERFINANCIERA
#
#                   REGIÓN DEPARTAMENTO DOMICILIO         CIUDAD DOMICILIO  \
# 0  Bogotá - Cundinamarca            BOGOTA D.C.  BOGOTA-D.C.-BOGOTA D.C.
# 1  Bogotá - Cundinamarca            BOGOTA D.C.  BOGOTA-D.C.-BOGOTA D.C.
#
#                                                 CIIU           MACROSECTOR  \
# 0               B0610 - Extracción de petróleo crudo  MINERO-HIDROCARBUROS
# 1  G4661 - Comercio al por mayor de combustibles ...              COMERCIO
#
#    INGRESOS OPERACIONALES\n2018*  GANANCIA (PERDIDA) 2018  TOTAL ACTIVOS 2018  \
# 0                   6.257985e+10             1.155640e+10        1.137618e+11
# 1                   1.487944e+10             1.337414e+08        5.488096e+09
#
#    TOTAL PASIVOS 2018  TOTAL PATRIMONIO 2018  INGRESOS OPERACIONALES\n2017*  \
# 0        5.654822e+10           5.721361e+10                   4.968708e+10
# 1        3.525498e+09           1.962597e+09                   1.249326e+10
#
#    GANANCIA (PERDIDA) 2017  TOTAL ACTIVOS 2017  TOTAL PASIVOS 2017  \
# 0             6.620412e+09        1.075490e+11        5.965040e+10
# 1             1.952812e+08        3.863475e+09        2.186212e+09
#
#    TOTAL PATRIMONIO 2017        GRUPO EN NIIF
# 0           4.789863e+10  NIIF PLENAS-GRUPO 1
# 1           1.677263e+09  NIIF PLENAS-GRUPO 1

# %%
df1 = df.loc[0:10]
plt.plot(df1['RAZON SOCIAL'], df1['TOTAL PATRIMONIO 2018'], label = 'Patrimonio 2018')
plt.plot(df1['RAZON SOCIAL'], df1['TOTAL PATRIMONIO 2017'], label = 'Patrimonio 2017')
plt.xticks(rotation=90)
plt.legend()
plt.title('Patrimonio de las 10 empresas más grandes de Col')
plt.show()

# %% [markdown]
# A partir del gráfico podemos ver que Ecopetrol es, con diferencia, la empresa con mayor patrimonio para el año 2018, convirtiéndola en la empresa más grande del país para ese año

# %%
# Set figure default figure size
plt.rcParams["figure.figsize"] = (10, 6)

x = df1['RAZON SOCIAL']
y = df1['TOTAL ACTIVOS 2018']
z = df1['TOTAL PASIVOS 2018']

plt.plot(
    x,y, ls="--", lw=3, 
    marker="X", markersize=10, markerfacecolor="red", markeredgecolor="black",
    label="Activos 2018"
)
plt.plot(
    x, z, ls=":", 
    marker="o", markersize=15, markerfacecolor="None", 
    label="Pasivos 2018"
)
plt.xticks(rotation=90)
plt.legend()
plt.show()

# %%
dfV = pd.read_csv('/content/drive/MyDrive/2023-I/Programación para ingeniería/Entradas_de_extranjeros_a_Colombia.csv') #Filtrado por procedentes de venezuela
dfV.head(5)
# Out:
#     Año    Mes Nacionalidad  Codigo Iso 3166  Femenino  Masculino  Indefinido  \
# 0  2012  Enero    Venezuela              862       297        339         NaN
# 1  2012  Enero    Venezuela              862         7         12         NaN
# 2  2012  Enero    Venezuela              862        76        133         NaN
# 3  2012  Enero    Venezuela              862        55         70         NaN
# 4  2012  Enero    Venezuela              862         0          4         NaN
#
#    Total      Latitud - Longitud
# 0    636   (0.814836,-77.662532)
# 1     19  (10.408582,-75.538003)
# 2    209  (10.445761,-75.516429)
# 3    125  (10.886611,-74.776708)
# 4      4  (11.117806,-74.232622)

# %%
dfVA = dfV.groupby(by = "Año").sum()
dfVA.drop(["Codigo Iso 3166", "Indefinido"], axis = 1, inplace = True)
dfVA
# Out:
#       Femenino  Masculino    Total
# Año
# 2012    113984     137491   251475
# 2013    117070     144273   261343
# 2014    130497     161042   291539
# 2015    152167     177311   329478
# 2016    175508     203457   378965
# 2017    368286     427948   796234
# 2018    658108     701671  1359815
# 2019    576251     519415  1095706
# 2020     97554      92322   189876
# 2021    131897     128724   260627
# 2022    105201     100161   205413

# %%
x = [2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022]
Hombres = dfVA["Masculino"]
Mujeres = dfVA["Femenino"]

# establecer el ancho de las barras
width = 0.35
p1 = plt.bar(x, Hombres, width)
p2 = plt.bar(x, Mujeres, width, bottom=Hombres)

plt.ylabel('Total ingresos')
plt.title('Ingreso de ciudadanos venezolanos a Colombia')
plt.legend((p1[0], p2[0]), ('Hombres', 'Mujeres'))

plt.show()
